# %% [markdown]
# <a href="https://colab.research.google.com/github/OmarMoghazy/Enozom/blob/main/Enozom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import hashlib

# %% [markdown]
# Read the csv file into a pandas dataframe

# %%
df1 = pd.read_csv('/content/drive/MyDrive/annual-enterprise-survey-2020-financial-year-provisional-csv.csv')
df1.head()
# Out:
#    Year  ...                             Industry_code_ANZSIC06
# 0  2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 1  2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 2  2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 3  2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 4  2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
#
# [5 rows x 10 columns]

# %% [markdown]
# Select odd rows and third column

# %%
df2 = df.iloc[::2,2]
df2
# Out:
# 0        99999
# 4        99999
# 8        99999
# 12       99999
# 16       99999
#          ...
# 37060     ZZ11
# 37064     ZZ11
# 37068     ZZ11
# 37072     ZZ11
# 37076     ZZ11
# Name: Industry_code_NZSIOC, Length: 9270, dtype: object

# %% [markdown]
# Join all values in the produced column into a single string

# %%
to_be_encoded = ''.join(np.array(df2).flatten().astype('str'))
to_be_encoded
# Out:
# '...'

# %% [markdown]
# Encode the result

# %%
result = hashlib.md5(to_be_encoded.encode()).hexdigest()
result
# Out:
# '416c3537ad1765f8458b92b6ff0e63b4'

# %% [markdown]
# # Test Case

# %%
test = pd.read_csv('/content/drive/MyDrive/testcase.csv')
test
# Out:
#       Name              Email  age  gender
# 0  mohamed  mohamed@gmail.com   22    male
# 1     noha     noha@gmail.com   21  female
# 2     alaa    aslaa@gmail.com   25  female

# %%
df4 = test.iloc[::2,2]
df4
# Out:
# 0    22
# 2    25
# Name: age, dtype: int64

# %%
to_be_encoded_test = ''.join(np.array(df4).flatten().astype('str'))
to_be_encoded_test
# Out:
# '2225'

# %%
result = hashlib.md5(to_be_encoded_test.encode()).hexdigest()
result
# Out:
# '443dec3062d0286986e21dc0631734c9'
